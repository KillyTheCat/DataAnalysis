# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace (-10,10,100)

# %%
y = np.cos(x)

# %%
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
y
# Out:
# array([ 0.54402111,  0.36459873,  0.17034683, -0.03083368, -0.23076008,
#        -0.42130064, -0.59470541, -0.74392141, -0.86287948, -0.94674118,
#        -0.99209556, -0.99709789, -0.96154471, -0.8868821 , -0.77614685,
#        -0.63384295, -0.46575841, -0.27872982, -0.0803643 ,  0.12126992,
#         0.31797166,  0.50174037,  0.66510151,  0.80141062,  0.90512352,
#         0.97202182,  0.99938456,  0.98609877,  0.93270486,  0.84137452,
#         0.7158225 ,  0.56115544,  0.38366419,  0.19056796, -0.01027934,
#        -0.21070855, -0.40256749, -0.57805259, -0.73002623, -0.85230712,
#        -0.93992165, -0.98930624, -0.99845223, -0.96698762, -0.8961922 ,
#        -0.78894546, -0.64960951, -0.48385164, -0.2984138 , -0.10083842,
#         0.10083842,  0.2984138 ,  0.48385164,  0.64960951,  0.78894546,
#         0.8961922 ,  0.96698762,  0.99845223,  0.98930624,  0.93992165,
#         0.85230712,  0.73002623,  0.57805259,  0.40256749,  0.21070855,
# ...

# %%
y = (x**2) + (x*2) + 7

# %%
y
# Out:
# array([ 87.        ,  83.40444853,  79.89052138,  76.45821855,
#         73.10754005,  69.83848587,  66.65105601,  63.54525048,
#         60.52106928,  57.5785124 ,  54.71757984,  51.9382716 ,
#         49.2405877 ,  46.62452811,  44.09009285,  41.63728191,
#         39.2660953 ,  36.97653301,  34.76859504,  32.6422814 ,
#         30.59759208,  28.63452709,  26.75308642,  24.95327007,
#         23.23507805,  21.59851036,  20.04356698,  18.57024793,
#         17.17855321,  15.86848281,  14.64003673,  13.49321498,
#         12.42801755,  11.44444444,  10.54249566,   9.72217121,
#          8.98347107,   8.32639527,   7.75094378,   7.25711662,
#          6.84491378,   6.51433527,   6.26538108,   6.09805122,
#          6.01234568,   6.00826446,   6.08580757,   6.244975  ,
#          6.48576676,   6.80818284,   7.21222324,   7.69788797,
#          8.26517702,   8.9140904 ,   9.6446281 ,  10.45679012,
#         11.35057647,  12.32598714,  13.38302214,  14.52168146,
# ...

# %%
plt.plot(x,y)

# %%
import pandas as pd

# %%
movie = pd.read_csv("bollywood.csv")

# %%
movie
# Out:
#          imdbId                                title  releaseYear  \
# 0     tt0118578                               Albela         2001
# 1     tt0169102    Lagaan: Once Upon a Time in India         2001
# 2     tt0187279             Meri Biwi Ka Jawab Nahin         2004
# 3     tt0222024               Hum Tumhare Hain Sanam         2002
# 4     tt0227194                           One 2 Ka 4         2001
# 5     tt0238936                               Devdas         2002
# 6     tt0247911          Aap Mujhe Achche Lagne Lage         2002
# 7     tt0248126          Kabhi Khushi Kabhie Gham...         2001
# 8     tt0248216                  Na Tum Jaano Na Hum         2002
# 9     tt0248617                           Yaadein...         2001
# 10    tt0255713                             Zubeidaa         2001
# 11    tt0256692            Chori Chori Chupke Chupke         2001
# 12    tt0265148             Main Prem Ki Diwani Hoon         2003
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null float64
# hitFlop        1284 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
movie.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
movie.shape
# Out:
# (1284, 10)

# %%
sum
# Out:
#          imdbId                         title  releaseYear  releaseDate  \
# 423   tt0479674                  Gumnam Qatil         2001  02 May 2001
# 438   tt0488287                       Darwaza         2002          NaN
# 513   tt0874854           Anjaane: The Unkown         2005  30 Dec 2005
# 536   tt0991267                       30 Days         2004          NaN
# 876   tt1772762  Bachao - Inside Bhoot Hai...         2010  08 Oct 2010
# 1019  tt2175671                         Ghost         2012  13 Jan 2012
# 1041  tt2208248       Machhli Jal Ki Rani Hai         2014  13 Jun 2014
# 1057  tt2234328                      Siyaah..         2012  11 Jul 2012
# 1127  tt2406636                 Bhoot Returns         2012  12 Oct 2012
# 1161  tt2691010              Mumbai 125 KM 3D         2014  17 Oct 2014
# 1211  tt3177332                  Horror Story         2013  02 May 2014
# 1253  tt3592020                    Neighbours         2014  14 Mar 2014
# ...

# %%
movie[movie['genre']=="Horror"]
# Out:
#          imdbId                         title  releaseYear  releaseDate  \
# 423   tt0479674                  Gumnam Qatil         2001  02 May 2001
# 438   tt0488287                       Darwaza         2002          NaN
# 513   tt0874854           Anjaane: The Unkown         2005  30 Dec 2005
# 536   tt0991267                       30 Days         2004          NaN
# 876   tt1772762  Bachao - Inside Bhoot Hai...         2010  08 Oct 2010
# 1019  tt2175671                         Ghost         2012  13 Jan 2012
# 1041  tt2208248       Machhli Jal Ki Rani Hai         2014  13 Jun 2014
# 1057  tt2234328                      Siyaah..         2012  11 Jul 2012
# 1127  tt2406636                 Bhoot Returns         2012  12 Oct 2012
# 1161  tt2691010              Mumbai 125 KM 3D         2014  17 Oct 2014
# 1211  tt3177332                  Horror Story         2013  02 May 2014
# 1253  tt3592020                    Neighbours         2014  14 Mar 2014
# ...

# %%
movie[movie['hitFlop']>6].shape
# Out:
# (53, 10)

# %%
mask1 = movie['genre']=="Romance"
mask2 = movie['hitFlop']>=6
movie[mask1 & mask2]
#movie[mask1 & mask2].shape
# Out:
#         imdbId                  title  releaseYear  releaseDate    genre  \
# 33   tt0284328  Mujhe Kucch Kehna Hai         2001  25 May 2001  Romance
# 150  tt0348258       Tujhe Meri Kasam         2003  03 Jan 2003  Romance
# 863  tt1729637              Bodyguard         2011  31 Aug 2011  Romance
#
#                                                writers  \
# 33       Rumi Jaffery (story) | A. Karunakaran (story)
# 150                             Neeraj Vora (dialogue)
# 863  J.P. Chowksey (screenplay) | Kiran Kotrial (sc...
#
#                                                 actors         directors  \
# 33   Tusshar Kapoor | Kareena Kapoor | Amrish Puri ...    Satish Kaushik
# 150  Ritesh Deshmukh | Shakti Kapoor | Supriya Karn...  Vijay K. Bhaskar
# 863  Salman Khan | Kareena Kapoor | Raj Babbar | As...          Siddique
#
#      sequel  hitFlop
# 33      0.0        7
# 150     0.0        6
# 863     0.0        8

# %%
movie.iloc[:10:2,[1,2,5,9]]
# Out:
#                          title  releaseYear  \
# 0                       Albela         2001
# 2     Meri Biwi Ka Jawab Nahin         2004
# 4                   One 2 Ka 4         2001
# 6  Aap Mujhe Achche Lagne Lage         2002
# 8          Na Tum Jaano Na Hum         2002
#
#                                              writers  hitFlop
# 0  Honey Irani (screenplay) | Honey Irani (story)...        2
# 2                                                NaN        1
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...        1
# 6  Robin Bhatt (story) | Girish Dhamija (dialogue...        2
# 8         Pratibha Acharya (dialogue) | Arjun Sablok        1

# %%
movie.sort_values('title',ascending = False)
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 10    tt0255713                            Zubeidaa         2001  19 Jan 2001
# 770   tt1479857              Zor Lagaa Ke... Haiya!         2009  12 Jun 2009
# 806   tt1605790                            Zokkomon         2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam         2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara         2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai         2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50         2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks         2006  06 Oct 2006
# 445   tt0488906                               Zinda         2006  12 Jan 2006
# 1283  tt4228746                                 Zid         2014  28 Nov 2014
# 364   tt0451983                               Zeher         2005  25 Mar 2005
# ...

# %%
movie.sort_values('releaseYear',inplace = True)

# %%
movie
# Out:
#          imdbId                             title  releaseYear  releaseDate  \
# 0     tt0118578                            Albela         2001  20 Apr 2001
# 53    tt0301179                       Deewaanapan         2001  16 Nov 2001
# 52    tt0300028                            Indian         2001  26 Oct 2001
# 51    tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# 50    tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 48    tt0297983                           Ittefaq         2001  14 Sep 2001
# 54    tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# 45    tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# 42    tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 41    tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# ...

# %%
##inplace makes the changes permanent

# %%
movie.sort_values(['releaseYear','releaseDate'],ascending = [False,True])
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 1252  tt3585758                Kahin Hai Mera Pyar         2014  01 May 2014
# 1262  tt3681414                       Purani Jeans         2014  02 May 2014
# 987   tt2063745               Kya Dilli Kya Lahore         2014  02 May 2014
# 1230  tt3390572                             Haider         2014  02 Oct 2014
# 1180  tt2905838                          Bang Bang         2014  02 Oct 2014
# 1179  tt2876408                 Mr Joe B. Carvalho         2014  03 Jan 2014
# 1165  tt2762334                     Main Tera Hero         2014  04 Apr 2014
# 1265  tt3716142              Lekar Hum Deewana Dil         2014  04 Jul 2014
# 1225  tt3359290                       Bobby Jasoos         2014  04 Jul 2014
# 1277  tt4045666                Mumbai Delhi Mumbai         2014  05 Dec 2014
# 253   tt0403935                     Action Jackson         2014  05 Dec 2014
# ...

# %%
movie['imdbId'].is_unique
# Out:
# True

# %%
movie.set_index('imdbId')
# Out:
#                                       title  releaseYear  releaseDate  \
# imdbId
# tt0118578                            Albela         2001  20 Apr 2001
# tt0301179                       Deewaanapan         2001  16 Nov 2001
# tt0300028                            Indian         2001  26 Oct 2001
# tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# tt0297983                           Ittefaq         2001  14 Sep 2001
# tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# tt0292490                    Dil Chahta Hai         2001  24 Jul 2001
# ...

# %%
movie
# Out:
#          imdbId                             title  releaseYear  releaseDate  \
# 0     tt0118578                            Albela         2001  20 Apr 2001
# 53    tt0301179                       Deewaanapan         2001  16 Nov 2001
# 52    tt0300028                            Indian         2001  26 Oct 2001
# 51    tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# 50    tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 48    tt0297983                           Ittefaq         2001  14 Sep 2001
# 54    tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# 45    tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# 42    tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 41    tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# ...

# %%
movie.reset_index()
# Out:
#       index     imdbId                             title  releaseYear  \
# 0         0  tt0118578                            Albela         2001
# 1        53  tt0301179                       Deewaanapan         2001
# 2        52  tt0300028                            Indian         2001
# 3        51  tt0299108         Rehnaa Hai Terre Dil Mein         2001
# 4        50  tt0298607              Yeh Zindagi Ka Safar         2001
# 5        49  tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001
# 6        48  tt0297983                           Ittefaq         2001
# 7        54  tt0301240                 Moksha: Salvation         2001
# 8        45  tt0295603                   Shirdi Sai Baba         2001
# 9        42  tt0292740          Yeh Raaste Hain Pyaar Ke         2001
# 10       41  tt0292552                Hum Ho Gaye Aap Ke         2001
# 11       40  tt0292490                    Dil Chahta Hai         2001
# ...

# %%
movie['title']
# Out:
# 0                                 Albela
# 53                           Deewaanapan
# 52                                Indian
# 51             Rehnaa Hai Terre Dil Mein
# 50                  Yeh Zindagi Ka Safar
# 49         Yeh Teraa Ghar Yeh Meraa Ghar
# 48                               Ittefaq
# 54                     Moksha: Salvation
# 45                       Shirdi Sai Baba
# 42              Yeh Raaste Hain Pyaar Ke
# 41                    Hum Ho Gaye Aap Ke
# 40                        Dil Chahta Hai
# 39                  Nayak: The Real Hero
# 38      Tum Bin...: Love Will Find a Way
# 37                                   Aks
# 43                                 Lajja
# 36                                Uljhan
# 55                 Tera Mera Saath Rahen
# 57                         Veer Savarkar
# 244      Hadh: Life on the Edge of Death
# 393                              Bhairav
# 420                         Bengal Tiger
# 216                               Master
# ...

# %%
def hitYaflop(number):
    if number>=6:
        return 'Hit'
    else:
        return 'Flop'

# %%
hitYaflop(7)
# Out:
# 'Hit'

# %%
movie['verdict']= movie['hitFlop'].apply(hitYaflop)

# %%
movie
# Out:
#          imdbId                             title  releaseYear  releaseDate  \
# 0     tt0118578                            Albela         2001  20 Apr 2001
# 53    tt0301179                       Deewaanapan         2001  16 Nov 2001
# 52    tt0300028                            Indian         2001  26 Oct 2001
# 51    tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# 50    tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 48    tt0297983                           Ittefaq         2001  14 Sep 2001
# 54    tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# 45    tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# 42    tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 41    tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# ...

# %%
movie['verdict']
# Out:
# 0       Flop
# 53      Flop
# 52       Hit
# 51      Flop
# 50      Flop
# 49      Flop
# 48      Flop
# 54      Flop
# 45      Flop
# 42      Flop
# 41      Flop
# 40      Flop
# 39      Flop
# 38      Flop
# 37      Flop
# 43      Flop
# 36      Flop
# 55      Flop
# 57      Flop
# 244     Flop
# 393     Flop
# 420     Flop
# 216     Flop
# 423     Flop
# 509     Flop
# 56      Flop
# 526     Flop
# 139     Flop
# 595     Flop
# 83      Flop
#         ...
# 1226    Flop
# 1047    Flop
# 1186    Flop
# 987     Flop
# 1223    Flop
# 1221     Hit
# 1220    Flop
# 1218    Flop
# 1217    Flop
# 1216    Flop
# 502     Flop
# 1210    Flop
# 1208    Flop
# 1205     Hit
# 1282    Flop
# 1202    Flop
# 1029    Flop
# 1035    Flop
# 1199    Flop
# 1198    Flop
# 1196    Flop
# 1195    Flop
# 1041    Flop
# 1193    Flop
# 1192    Flop
# 1190    Flop
# 1189    Flop
# 1188    Flop
# 1046    Flop
# 1283    Flop
# Name: verdict, Length: 1284, dtype: object

# %%
movie['releaseYear'].value_counts()
# Out:
# 2010    116
# 2011    112
# 2014    110
# 2005    106
# 2013    102
# 2012     99
# 2008     98
# 2003     95
# 2009     91
# 2004     88
# 2002     79
# 2007     66
# 2001     62
# 2006     60
# Name: releaseYear, dtype: int64

# %%
movie['releaseYear'].value_counts().index[-1]
# Out:
# 2006

# %%
movie.drop('actors',axis=1)
# Out:
#          imdbId                             title  releaseYear  releaseDate  \
# 0     tt0118578                            Albela         2001  20 Apr 2001
# 53    tt0301179                       Deewaanapan         2001  16 Nov 2001
# 52    tt0300028                            Indian         2001  26 Oct 2001
# 51    tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# 50    tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 48    tt0297983                           Ittefaq         2001  14 Sep 2001
# 54    tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# 45    tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# 42    tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 41    tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# ...

# %%
print(movie)
# Out:
#          imdbId                                title  releaseYear  \
# 0     tt0118578                               Albela         2001
# 1     tt0169102    Lagaan: Once Upon a Time in India         2001
# 2     tt0187279             Meri Biwi Ka Jawab Nahin         2004
# 3     tt0222024               Hum Tumhare Hain Sanam         2002
# 4     tt0227194                           One 2 Ka 4         2001
# 5     tt0238936                               Devdas         2002
# 6     tt0247911          Aap Mujhe Achche Lagne Lage         2002
# 7     tt0248126          Kabhi Khushi Kabhie Gham...         2001
# 8     tt0248216                  Na Tum Jaano Na Hum         2002
# 9     tt0248617                           Yaadein...         2001
# 10    tt0255713                             Zubeidaa         2001
# 11    tt0256692            Chori Chori Chupke Chupke         2001
# 12    tt0265148             Main Prem Ki Diwani Hoon         2003
# ...

# %%
movie.info
# Out:
# <bound method DataFrame.info of          imdbId                             title  releaseYear  releaseDate  \
# 0     tt0118578                            Albela         2001  20 Apr 2001
# 53    tt0301179                       Deewaanapan         2001  16 Nov 2001
# 52    tt0300028                            Indian         2001  26 Oct 2001
# 51    tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# 50    tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 48    tt0297983                           Ittefaq         2001  14 Sep 2001
# 54    tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# 45    tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# 42    tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 41    tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# ...

# %%
movie.dropna(subset=['writers'])
# Out:
#          imdbId                             title  releaseYear  releaseDate  \
# 0     tt0118578                            Albela         2001  20 Apr 2001
# 53    tt0301179                       Deewaanapan         2001  16 Nov 2001
# 52    tt0300028                            Indian         2001  26 Oct 2001
# 51    tt0299108         Rehnaa Hai Terre Dil Mein         2001  19 Oct 2001
# 50    tt0298607              Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606     Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 48    tt0297983                           Ittefaq         2001  14 Sep 2001
# 54    tt0301240                 Moksha: Salvation         2001  30 Nov 2001
# 45    tt0295603                   Shirdi Sai Baba         2001  07 Sep 2001
# 42    tt0292740          Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 41    tt0292552                Hum Ho Gaye Aap Ke         2001  03 Aug 2001
# ...

# %%
movie.dropna(subset=['writers','sequel']).shape
# Out:
# (1163, 11)

# %%
movie.fillna({'writers':"No Writer"},inplace = True)

# %% [markdown]
# mo

# %%
movie.drop_duplicates().shape
# Out:
# (1284, 11)

# %%
movie.drop_duplicates(subset=['releaseYear']).shape
# Out:
# (14, 11)

# %%
movie.drop_duplicates(subset=['releaseYear'], keep='last').shape
# Out:
# (14, 11)

# %%
food = pd.read_csv('food.csv')

# %%
company = pd.read_csv('Fortune501.csv')

# %%
company
# Out:
#      Rank                               Title  Employees  \
# 0       1                             Walmart    2300000
# 1       2                  Berkshire Hathaway     367700
# 2       3                               Apple     116000
# 3       4                         Exxon Mobil      72700
# 4       5                            McKesson      68000
# 5       6                  UnitedHealth Group     230000
# 6       7                          CVS Health     204000
# 7       8                      General Motors     225000
# 8       9                                AT&T     268540
# 9      10                          Ford Motor     201000
# 10     11                   AmerisourceBergen      18500
# 11     12                          Amazon.com     341400
# 12     13                    General Electric     295000
# 13     14                             Verizon     160900
# 14     15                     Cardinal Health      37300
# ...

# %%
sectors = company.groupby('Sector')

# %%
sectors.sort_values(ascending = False).index[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-6f43c83a6c6b> in <module>
# ----> 1 sectors.sort_values(ascending = False).index[0]
#
# D:\Conda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# D:\Conda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# ...

# %% [raw]
# company

# %%
company['Sector'].value_counts()
# Out:
# Financials                       84
# Energy                           57
# Retailing                        47
# Technology                       43
# Health Care                      38
# Wholesalers                      29
# Food, Beverages & Tobacco        24
# Business Services                20
# Materials                        19
# Industrials                      19
# Transportation                   17
# Chemicals                        14
# Engineering & Construction       13
# Aerospace & Defense              12
# Household Products               12
# Media                            11
# Telecommunications               10
# Hotels, Restaurants & Leisure    10
# Motor Vehicles & Parts            9
# Food & Drug Stores                7
# Apparel                           5
# Name: Sector, dtype: int64

# %%
sectors = company.groupby('Sector')

# %%
sectors.sum()['Profits'].sort_values(ascending = False)
# Out:
# Sector
# Financials                       228461.2
# Technology                       177901.4
# Health Care                      105383.9
# Food, Beverages & Tobacco         56308.4
# Retailing                         46613.9
# Telecommunications                41272.8
# Industrials                       32826.1
# Transportation                    28395.0
# Aerospace & Defense               25119.7
# Business Services                 23107.1
# Media                             20034.7
# Household Products                19803.7
# Motor Vehicles & Parts            17275.8
# Chemicals                         15918.3
# Hotels, Restaurants & Leisure     14510.6
# Wholesalers                       11347.1
# Food & Drug Stores                 8522.0
# Apparel                            6318.5
# Materials                          5176.9
# Engineering & Construction         5072.2
# Energy                              370.6
# Name: Profits, dtype: float64

# %%
sectors.get_group('Financials')
# Out:
#      Rank                                Title  Employees  \
# 1       2                   Berkshire Hathaway     367700
# 19     20                           Fannie Mae       7000
# 20     21                    J.P. Morgan Chase     243355
# 24     25                          Wells Fargo     269100
# 25     26                Bank of America Corp.     208024
# 29     30                            Citigroup     219000
# 32     33            State Farm Insurance Cos.      68234
# 38     39                          Freddie Mac       5982
# 41     42                              MetLife      58000
# 47     48                 Prudential Financial      49739
# 54     55                                  AIG      56400
# 64     65              New York Life Insurance      11320
# 67     68                           Nationwide      34320
# 74     75       Liberty Mutual Insurance Group      50000
# 75     76                       Morgan Stanley      55311
# ...
